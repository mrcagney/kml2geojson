# %%
import fastkml

data_dir = '../data/'

# %%
with open(data_dir + 'bundle_02/doc.kml', 'r') as src:
    doc = src.read()

k = fastkml.KML()
k.from_string(doc)
k.to_string(prettyprint=True)
# Out:
# WARNING:fastkml.kml:No geometries found
# WARNING:fastkml.kml:No geometries found
# ERROR:fastkml.kml:Object does not have a geometry
# ERROR:fastkml.kml:Object does not have a geometry
# ...
