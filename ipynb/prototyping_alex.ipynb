# %%
import json
import sys
import subprocess
from copy import deepcopy
import pathlib
import xml.dom.minidom as md

data_dir = '../tests/data/'
out_dir = '../outputs/'

sys.path.append('../')
import kml2geojson as kg

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
name = 'google_sample'
kml_path = data_dir + name + '.kml'
geojson_path = data_dir + name + '.geojson'

with open(kml_path) as src:
    root = md.parseString(src.read())

get = kg.build_feature_collection(root)
json.dumps(get, indent=2)

# with open(geojson_path) as src:
#    expect = json.load(src)

# get == expect
# Out:
# '{\n  "type": "FeatureCollection",\n  "features": [\n    {\n      "properties": {\n        "name": "Simple placemark",\n        "description": "Attached to the ground. Intelligently places itself at the\\n          height of the underlying terrain."\n      },\n      "type": "Feature",\n      "geometry": {\n        "type": "Point",\n        "coordinates": [\n          -122.0822035425683,\n          37.42228990140251,\n          0.0\n        ]\n      }\n    },\n    {\n      "properties": {\n        "name": "Floating placemark",\n        "styleUrl": "#downArrowIcon",\n        "description": "Floats a defined distance above the ground."\n      },\n      "type": "Feature",\n      "geometry": {\n        "type": "Point",\n        "coordinates": [\n          -122.084075,\n          37.4220033612141,\n          50.0\n        ]\n      }\n    },\n    {\n      "properties": {\n        "name": "Extruded placemark",\n        "styleUrl": "#globeIcon",\n        "description": "Tethered to the ground by a customizable\\n          \\"tail\\""\n      },\n      "type": "Feature",\n      "geometry": {\n        "type": "Point",\n        "coordinates": [\n          -122.0857667006183,\n          37.42156927867553,\n          50.0\n        ]\n      }\n    },\n    {\n      "properties": {\n        "name": "Roll over this icon",\n        "styleUrl": "#exampleStyleMap"\n      },\n      "type": "Feature",\n      "geometry": {\n        "type": "Point",\n        "coordinates": [\n          -122.0856545755255,\n          37.42243077405461,\n          0.0\n        ]\n      }\n    },\n    {\n      "properties": {\n        "name": "Tessellated",\n        "description": "If the <tessellate> tag has a value of 1, the line will contour to the underlying terrain"\n      },\n      "type": "Feature",\n      "geometry": {\n        "type": "LineString",\n        "coordinates": [\n          [\n            -112.0814237830345,\n            36.10677870477137,\n            0.0\n          ],\n          [\n            -112.0870267752693,\n            36.0905099328766,\n            0.0\n          ]\n        ]\n      }\n    },\n    {\n      "properties": {\n        "name": "Untessellated",\n        "description": "If the <tessellate> tag has a value of 0, the line follow a simple straight-line path from point to point"\n      },\n      "type": "Feature",\n      "geometry": {\n        "type": "LineString",\n        "coordinates": [\n          [\n            -112.080622229595,\n            36.10673460007995,\n            0.0\n          ],\n          [\n            -112.085242575315,\n            36.09049598612422,\n            0.0\n          ]\n        ]\n      }\n    },\n    {\n      "properties": {\n        "name": "Absolute",\n        "styleUrl": "#transPurpleLineGreenPoly",\n        "description": "Transparent purple line"\n      },\n      "type": "Feature",\n      "geometry": {\n        "type": "LineString",\n        "coordinates": [\n          [\n            -112.265654928602,\n            36.09447672602546,\n            2357.0\n          ],\n          [\n            -112.2660384528238,\n            36.09342608838671,\n            2357.0\n          ],\n          [\n            -112.2668139013453,\n            36.09251058776881,\n            2357.0\n          ],\n          [\n            -112.2677826834445,\n            36.09189827357996,\n            2357.0\n          ],\n          [\n            -112.2688557510952,\n            36.0913137941187,\n            2357.0\n          ],\n          [\n            -112.2694810717219,\n            36.0903677207521,\n            2357.0\n          ],\n          [\n            -112.2695268555611,\n            36.08932171487285,\n            2357.0\n          ],\n          [\n            -112.2690144567276,\n            36.08850916060472,\n            2357.0\n          ],\n          [\n            -112.2681528815339,\n            36.08753813597956,\n            2357.0\n          ],\n          [\n            -112.2670588176031,\n         ...

# %%
x = kg.build_feature_collection(root)
with open(data_dir + 'linestring.geojson') as src:
    y = json.load(src)
x == y
# Out:
# True

# %%
kml_path = data_dir + 'inline_style.kml'
output_dir = out_dir + 'example_01'
kg.kml2geojson(kml_path, output_dir, style_type='leaflet', 
  separate_layers=False)
