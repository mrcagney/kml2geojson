# %%
import json
import sys
import subprocess
from copy import deepcopy

import xmltodict

data_dir = '../data/'
out_dir = '../outputs/'

sys.path.append('../')
import kml2geojson as kg

# %load_ext autoreload
# %autoreload 2

# %%
with open(data_dir + 'example_02/doc.kml', 'r') as src:
    kml_str = src.read()

x = xmltodict.parse(kml_str)

# %%
for folder in x['kml']['Document']['Folder']:
    y = deepcopy(x)
    y['kml']['Document']['Folder'] = [folder]
    kml_str = xmltodict.unparse(y)
    kml_path = '/tmp/tmp.kml'
    with open(kml_path, 'w') as tgt:
        tgt.write(kml_str)
    

# features = folders[1]['Placemark']
# features
# ids = [f['@id'] for f in features]
# ids
# Out:
# '<?xml version="1.0" encoding="utf-8"?>\n<kml xmlns="http://www.opengis.net/kml/2.2" xmlns:gx="http://www.google.com/kml/ext/2.2" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.opengis.net/kml/2.2 http://schemas.opengis.net/kml/2.2.0/ogckml22.xsd http://www.google.com/kml/ext/2.2 http://code.google.com/apis/kml/schema/kml22gx.xsd"><Document id="Layers"><name>Layers</name><Snippet></Snippet><Folder id="FeatureLayer2"><name>Rapid Network Background</name><Snippet></Snippet><Placemark id="ID_20000"><name>1527</name><Snippet></Snippet><description>&lt;html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt"&gt;\n\n&lt;head&gt;\n\n&lt;META http-equiv="Content-Type" content="text/html"&gt;\n\n&lt;meta http-equiv="content-type" content="text/html; charset=UTF-8"&gt;\n\n&lt;/head&gt;\n\n&lt;body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;"&gt;\n\n&lt;table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px"&gt;\n\n&lt;tr style="text-align:center;font-weight:bold;background:#9CBCE2"&gt;\n\n&lt;td&gt;1527&lt;/td&gt;\n\n&lt;/tr&gt;\n\n&lt;tr&gt;\n\n&lt;td&gt;\n\n&lt;table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px"&gt;\n\n&lt;tr&gt;\n\n&lt;td&gt;segment_id&lt;/td&gt;\n\n&lt;td&gt;1527&lt;/td&gt;\n\n&lt;/tr&gt;\n\n&lt;tr bgcolor="#D4E4F3"&gt;\n\n&lt;td&gt;NN_Weekday&lt;/td&gt;\n\n&lt;td&gt;frequent&lt;/td&gt;\n\n&lt;/tr&gt;\n\n&lt;tr&gt;\n\n&lt;td&gt;NN_Sat&lt;/td&gt;\n\n&lt;td&gt;frequent&lt;/td&gt;\n\n&lt;/tr&gt;\n\n&lt;tr bgcolor="#D4E4F3"&gt;\n\n&lt;td&gt;NN_Sun&lt;/td&gt;\n\n&lt;td&gt;frequent&lt;/td&gt;\n\n&lt;/tr&gt;\n\n&lt;tr&gt;\n\n&lt;td&gt;temp&lt;/td&gt;\n\n&lt;td&gt;1527&lt;/td&gt;\n\n&lt;/tr&gt;\n\n&lt;tr bgcolor="#D4E4F3"&gt;\n\n&lt;td&gt;NN_Sun_2026&lt;/td&gt;\n\n&lt;td&gt;frequent&lt;/td&gt;\n\n&lt;/tr&gt;\n\n&lt;tr&gt;\n\n&lt;td&gt;NN_Sun_Steve&lt;/td&gt;\n\n&lt;td&gt;frequent&lt;/td&gt;\n\n&lt;/tr&gt;\n\n&lt;tr bgcolor="#D4E4F3"&gt;\n\n&lt;td&gt;NortherBusway&lt;/td&gt;\n\n&lt;td&gt;Northern Busway&lt;/td&gt;\n\n&lt;/tr&gt;\n\n&lt;/table&gt;\n\n&lt;/td&gt;\n\n&lt;/tr&gt;\n\n&lt;/table&gt;\n\n&lt;/body&gt;\n\n&lt;/html&gt;</description><styleUrl>#LineStyle20</styleUrl><MultiGeometry><LineString><extrude>0</extrude><altitudeMode>clampToGround</altitudeMode><coordinates>174.7518299997044,-36.8144999989312,0 174.7524599999024,-36.81414999932866,0 174.7530899995369,-36.81393999882443,0 174.7532770264955,-36.81388899229174,0 174.754080000384,-36.8136699989089,0 174.7544099994598,-36.81341999889975,0 174.754479999895,-36.81317999874337,0 174.7545475927039,-36.8128174593265,0 174.7545900002996,-36.81258999940548,0 174.7546142561606,-36.81248715598013,0 174.7546491220523,-36.81233932544698,0 174.7548399997069,-36.8115299987993,0 174.7552600002011,-36.81078999943735,0 174.7556000001429,-36.81030999943802,0 174.756930000374,-36.80884999893797,0 174.7575856100065,-36.8081209680289,0 174.7581800000346,-36.8074599995042,0 174.7591600000623,-36.80638999895932,0 174.7596701489905,-36.80572770068184,0 174.7597299998477,-36.80564999897077,0 174.7602699996934,-36.80468999871867,0 174.7607600000917,-36.80372999919226,0 174.7613399996423,-36.80240999947204,0 174.7617100002962,-36.80150999914131,0 174.7618394723148,-36.80117244702867,0 174.7619899999173,-36.8007799986809,0</coordinates></LineString></MultiGeometry></Placemark><Placemark id="ID_20001"><name>1537</name><Snippet></Snippet><description>&lt;html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt"&gt;\n\n&lt;head&gt;\n\n&lt;META http-equiv="Content-Type" content="text/html"&gt;\n\n&lt;meta http-equiv="content-type" content="text/html; charset=UTF-8"&gt;\n\n&lt;/head&gt;\n\n&lt;body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;"&gt;\n\n&lt;table style="font-family:Arial,Verd ...

# %%
gs = kg.build_geojsons(kml_str)
gs[0]
# Out:
# {'features': [{'geometry': {'coordinates': [174.7132760210829,
#      -36.7232526129301,
#      0],
#     'type': 'Point'},
#    'id': 'ID_00000',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Albany</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Albany</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Albany',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.75312007878, -36.73815523226028, 0],
#     'type': 'Point'},
#    'id': 'ID_00001',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Mairangi Bay</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Mairangi Bay</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Mairangi Bay',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.728007190231, -36.7514736934949, 0],
#     'type': 'Point'},
#    'id': 'ID_00002',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Constellation</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Constellation</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Constellation',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7509697847412, -36.78456766996173, 0],
#     'type': 'Point'},
#    'id': 'ID_00003',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Smales Farm</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Smales Farm</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>2</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Smales Farm',
#     'styleHash': '-7f364f53',
#     'styleUrl': '#IconStyle03'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.771478885758, -36.78770139464688, 0],
#     'type': 'Point'},
#    'id': 'ID_00004',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Takapuna</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Takapuna</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Takapuna',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7613953509286, -36.79719528151457, 0],
#     'type': 'Point'},
#    'id': 'ID_00005',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Akoranga</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Akoranga</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Akoranga',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7200633759217, -36.81140189298144, 0],
#     'type': 'Point'},
#    'id': 'ID_00006',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Highbury</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Highbury</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>2</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Highbury',
#     'styleHash': '-7f364f53',
#     'styleUrl': '#IconStyle03'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7050191114271, -36.80641315649887, 0],
#     'type': 'Point'},
#    'id': 'ID_00007',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Verrans Corner</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Verrans Corner</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Verrans Corner',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7960174182841, -36.83256207789649, 0],
#     'type': 'Point'},
#    'id': 'ID_00008',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Devonport</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Devonport</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>2</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Devonport',
#     'styleHash': '-7f364f53',
#     'styleUrl': '#IconStyle03'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7667798726249, -36.84405617456639, 0],
#     'type': 'Point'},
#    'id': 'ID_00009',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Britomart</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Britomart</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Britomart',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7628087135322, -36.8500352087903, 0],
#     'type': 'Point'},
#    'id': 'ID_00010',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Aotea</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Aotea</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Aotea',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7683376483196, -36.85384397721244, 0],
#     'type': 'Point'},
#    'id': 'ID_00011',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>University</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>University</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'University',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7709538577541, -36.86535505481416, 0],
#     'type': 'Point'},
#    'id': 'ID_00012',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Grafton</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Grafton</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>2</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Grafton',
#     'styleHash': '-7f364f53',
#     'styleUrl': '#IconStyle03'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.778086182902, -36.87098573571994, 0],
#     'type': 'Point'},
#    'id': 'ID_00013',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Newmarket</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Newmarket</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Newmarket',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7976502419153, -36.88090870790815, 0],
#     'type': 'Point'},
#    'id': 'ID_00014',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Remuera Village</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Remuera Village</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Remuera Village',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7985165780875, -36.88864667135933, 0],
#     'type': 'Point'},
#    'id': 'ID_00015',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Greenlane</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Greenlane</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Greenlane',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.8541395835397, -36.87791508167639, 0],
#     'type': 'Point'},
#    'id': 'ID_00016',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Glen Innes</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Glen Innes</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Glen Innes',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.8486633155718, -36.89844937731577, 0],
#     'type': 'Point'},
#    'id': 'ID_00017',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Penrose</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Penrose</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Penrose',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.8423152426601, -36.91362615131676, 0],
#     'type': 'Point'},
#    'id': 'ID_00018',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Sylvia Park</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Sylvia Park</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>2</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Sylvia Park',
#     'styleHash': '-7f364f53',
#     'styleUrl': '#IconStyle03'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.8698694004317, -36.91276954469634, 0],
#     'type': 'Point'},
#    'id': 'ID_00019',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Pakuranga Plaza</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Pakuranga Plaza</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>2</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Pakuranga Plaza',
#     'styleHash': '-7f364f53',
#     'styleUrl': '#IconStyle03'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.9119144774864, -36.93304255351315, 0],
#     'type': 'Point'},
#    'id': 'ID_00020',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Botany Town Centre</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Botany Town Centre</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Botany Town Centre',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.8441962495955, -36.94282633919814, 0],
#     'type': 'Point'},
#    'id': 'ID_00021',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Otahuhu Town Centre</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Otahuhu Town Centre</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>2</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Otahuhu Town Centre',
#     'styleHash': '-7f364f53',
#     'styleUrl': '#IconStyle03'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.8339770763171, -36.94567302726772, 0],
#     'type': 'Point'},
#    'id': 'ID_00022',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Otahuhu Train Station</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Otahuhu Train Station</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Otahuhu Train Station',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.8737262878719, -36.96244772795254, 0],
#     'type': 'Point'},
#    'id': 'ID_00023',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Otara</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Otara</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Otara',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.858781112795, -36.96763991650752, 0],
#     'type': 'Point'},
#    'id': 'ID_00024',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Hunters Corner</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Hunters Corner</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Hunters Corner',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.8513634432304, -36.97992405333523, 0],
#     'type': 'Point'},
#    'id': 'ID_00025',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Papatoetoe</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Papatoetoe</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Papatoetoe',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.8784909821499, -36.99433350321176, 0],
#     'type': 'Point'},
#    'id': 'ID_00026',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Manukau</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Manukau</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Manukau',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.8966631943187, -37.02319294268524, 0],
#     'type': 'Point'},
#    'id': 'ID_00027',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Manurewa</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Manurewa</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Manurewa',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.9460930185826, -37.06425418977432, 0],
#     'type': 'Point'},
#    'id': 'ID_00028',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Papakura</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Papakura</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Papakura',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7889274959683, -37.00184413869732, 0],
#     'type': 'Point'},
#    'id': 'ID_00029',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Airport Terminals</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Airport Terminals</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Airport Terminals',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7969055202641, -36.96643533599488, 0],
#     'type': 'Point'},
#    'id': 'ID_00030',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Mangere Town Centre</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Mangere Town Centre</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Mangere Town Centre',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7876827576936, -36.92428683194928, 0],
#     'type': 'Point'},
#    'id': 'ID_00031',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Onehunga</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Onehunga</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Onehunga',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7355560397917, -36.93030965218777, 0],
#     'type': 'Point'},
#    'id': 'ID_00032',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Hillsborough</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Hillsborough</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Hillsborough',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7232636342377, -36.92482168809428, 0],
#     'type': 'Point'},
#    'id': 'ID_00033',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Lynfield</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Lynfield</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Lynfield',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7420101346642, -36.90495737804572, 0],
#     'type': 'Point'},
#    'id': 'ID_00034',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td> </td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td></td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7600838998308, -36.90904798089843, 0],
#     'type': 'Point'},
#    'id': 'ID_00035',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td> </td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td></td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7744036528248, -36.89345669845854, 0],
#     'type': 'Point'},
#    'id': 'ID_00036',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Epsom</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Epsom</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Epsom',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7611273726866, -36.89043695564429, 0],
#     'type': 'Point'},
#    'id': 'ID_00037',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td> </td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td></td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7474866495609, -36.88710566014968, 0],
#     'type': 'Point'},
#    'id': 'ID_00038',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Balmoral</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Balmoral</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Balmoral',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7384000002334, -36.88511999928998, 0],
#     'type': 'Point'},
#    'id': 'ID_00039',
# ...
#     'name': 'Fruitvale Rd',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.8337341264936, -36.88874698178262, 0],
#     'type': 'Point'},
#    'id': 'ID_00115',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Stonefields</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Stonefields</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Stonefields',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7563701486686, -36.91595919970191, 0],
#     'type': 'Point'},
#    'id': 'ID_00116',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Hayr Rd</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Hayr Rd</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Hayr Rd',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.7387952911083, -36.91040486782281, 0],
#     'type': 'Point'},
#    'id': 'ID_00117',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Dominion</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Dominion</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Dominion',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.8406916959723, -36.96497711031081, 0],
#     'type': 'Point'},
#    'id': 'ID_00118',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Middlemore</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Middlemore</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Middlemore',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.9219512706251, -37.04392033998831, 0],
#     'type': 'Point'},
#    'id': 'ID_00119',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Te Mahia</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Te Mahia</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Te Mahia',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.9115120011141, -37.20275904913985, 0],
#     'type': 'Point'},
#    'id': 'ID_00120',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Pukekohe</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Pukekohe</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>2</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Pukekohe',
#     'styleHash': '-7f364f53',
#     'styleUrl': '#IconStyle03'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.6961374631026, -36.58530414145604, 0],
#     'type': 'Point'},
#    'id': 'ID_00121',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Orewa</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Orewa</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>2</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>0</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Orewa',
#     'styleHash': '-7f364f53',
#     'styleUrl': '#IconStyle03'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.6198274026959, -36.83265154965545, 0],
#     'type': 'Point'},
#    'id': 'ID_00122',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Royal Rd</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Royal Rd</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>2</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>&lt;Null&gt;</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Royal Rd',
#     'styleHash': '-7f364f53',
#     'styleUrl': '#IconStyle03'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.6769393783424, -36.66619564396999, 0],
#     'type': 'Point'},
#    'id': 'ID_00123',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Redvale</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Redvale</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>&lt;Null&gt;</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Redvale',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.6781330318581, -36.61814856972809, 0],
#     'type': 'Point'},
#    'id': 'ID_00124',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Silverdale</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Silverdale</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>3</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>&lt;Null&gt;</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Silverdale',
#     'styleHash': '-3e2790b6',
#     'styleUrl': '#IconStyle00'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.8951585438008, -37.16442625106735, 0],
#     'type': 'Point'},
#    'id': 'ID_00125',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Paerata</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Paerata</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>&lt;Null&gt;</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Paerata',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.9189583189917, -37.13577067363503, 0],
#     'type': 'Point'},
#    'id': 'ID_00126',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Karaka</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Karaka</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>1</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>&lt;Null&gt;</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Karaka',
#     'styleHash': '-525fecbc',
#     'styleUrl': '#IconStyle01'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [174.9468588326988, -37.10844506332876, 0],
#     'type': 'Point'},
#    'id': 'ID_00127',
#    'properties': {'description': '<html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n\n<head>\n\n<META http-equiv="Content-Type" content="text/html">\n\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n</head>\n\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n\n<td>Drury</td>\n\n</tr>\n\n<tr>\n\n<td>\n\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n\n<tr>\n\n<td>Name</td>\n\n<td>Drury</td>\n\n</tr>\n\n<tr bgcolor="#D4E4F3">\n\n<td>Type</td>\n\n<td>2</td>\n\n</tr>\n\n<tr>\n\n<td>Captype</td>\n\n<td>&lt;Null&gt;</td>\n\n</tr>\n\n</table>\n\n</td>\n\n</tr>\n\n</table>\n\n</body>\n\n</html>',
#     'name': 'Drury',
#     'styleHash': '-7f364f53',
#     'styleUrl': '#IconStyle03'},
#    'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
kml_path = data_dir + 'example_02/doc.kml'
geojson_path = out_dir + 'doc_02.geojson'
json_path = out_dir + 'doc_02.json'

kg.kml2geojson(kml_path, geojson_path, json_path)
